# %% [markdown]
# <a href="https://colab.research.google.com/github/junior141981/volta-zero/blob/main/module_9_exercise_agora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Scripting
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Instalando o Python na própria máquina;</li>
#   <li>Executando código Python no terminal;</li>
#   <li>Criando arquivos de script Python.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 0\. Preparando o ambiente

# %% [markdown]
#  - Instalando o Python e o PIP na sua máquina.

# %% [markdown]
# Nestes exercícios você vai precisar do Python (versão 3.x) e do PIP instalados na sua máquina. Abra o seu terminal (windows `cmd` ou linux/mcos `terminal`) e
# verifique se ambos estão instalados na sua máquina.
#
# ```shell
# python -V # possível resultado: Python 3.8.5
# pip -V # possível resultado: pip 20.0.2 ...
# ```
#
# Se pelo menos um dos softwares não estiver instalados na sua máquina, siga as instruções da aula para instala-los. Se você tiver enfrentando algum problema, entre em contato com o tutor.

# %% [markdown]
#  - Instalando os pacotes necessários.

# %% [markdown]
# Instale os pacotes necessários para conduzir os exercícios.
#
# ```shell
# pip install pandas==1.2.4 seaborn==0.11.1 requests==2.25.1
# ```

# %%
pip install pandas==1.2.4 seaborn==0.11.1 requests==2.25.1
# Out:
# Collecting pandas==1.2.4
#   Downloading pandas-1.2.4.tar.gz (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 29.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting seaborn==0.11.1
#   Downloading seaborn-0.11.1-py3-none-any.whl (285 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.0/285.0 kB 32.2 MB/s eta 0:00:00
# Collecting requests==2.25.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.2.4) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.10/dist-packages (from pandas==1.2.4) (2023.3.post1)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from pandas==1.2.4) (1.23.5)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from seaborn==0.11.1) (1.11.3)
# Requirement already satisfied: matplotlib>=2.2 in /usr/local/lib/python3.10/dist-packages (from seaborn==0.11.1) (3.7.1)
# Collecting chardet<5,>=3.0.2 (from requests==2.25.1)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 13.6 MB/s eta 0:00:00
# Collecting idna<3,>=2.5 (from requests==2.25.1)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.4 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1 (from requests==2.25.1)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests==2.25.1) (2023.7.22)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2->seaborn==0.11.1) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2->seaborn==0.11.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2->seaborn==0.11.1) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2->seaborn==0.11.1) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2->seaborn==0.11.1) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2->seaborn==0.11.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2->seaborn==0.11.1) (3.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.3->pandas==1.2.4) (1.16.0)
# Building wheels for collected packages: pandas
#   Building wheel for pandas (pyproject.toml) ... done
#   Created wheel for pandas: filename=pandas-1.2.4-cp310-cp310-linux_x86_64.whl size=34330617 sha256=1763daa5d9ffb91823e2d9b25f7e83d80a9e2852842d2f26e4f9b6f973fcdc70
#   Stored in directory: /root/.cache/pip/wheels/1b/10/28/2a37b26cf3e4dc59d82430e3812f8571518d2c1d81c288af98
# Successfully built pandas
# Installing collected packages: urllib3, idna, chardet, requests, pandas, seaborn
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# arviz 0.15.1 requires pandas>=1.3.0, but you have pandas 1.2.4 which is incompatible.
# bigframes 0.10.0 requires pandas>=1.5.0, but you have pandas 1.2.4 which is incompatible.
# bigframes 0.10.0 requires requests>=2.27.1, but you have requests 2.25.1 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 1.2.4 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.25.1 which is incompatible.
# ibis-framework 6.2.0 requires pandas<3,>=1.2.5, but you have pandas 1.2.4 which is incompatible.
# mizani 0.9.3 requires pandas>=1.3.5, but you have pandas 1.2.4 which is incompatible.
# plotnine 0.12.3 requires pandas>=1.5.0, but you have pandas 1.2.4 which is incompatible.
# tweepy 4.13.0 requires requests<3,>=2.27.0, but you have requests 2.25.1 which is incompatible.
# xarray 2023.7.0 requires pandas>=1.4, but you have pandas 1.2.4 which is incompatible.
# yfinance 0.2.31 requires pandas>=1.3.0, but you have pandas 1.2.4 which is incompatible.
# yfinance 0.2.31 requires requests>=2.31, but you have requests 2.25.1 which is incompatible.
# Successfully installed chardet-4.0.0 idna-2.10 pandas-1.2.4 requests-2.25.1 seaborn-0.11.1 urllib3-1.26.18

# %% [markdown]
# ---

# %% [markdown]
# ## 1\. Script de Extração

# %% [markdown]
# O *script* para extrair a taxa CDI do site da B3 foi adaptado para ser executado 10 vezes para gerar nossa base de dados. Na sua máquina, crie o arquivo `extracao.py` com o `script` abaixo e execute-o com o comando:
#
# ```shell
# python extracao.py
# ```
#
# No final, você deve ter o arquivo `taxa-cdi.csv` com os dados extraídos.

# %%
import os
import time
import json
from random import random
from datetime import datetime

import requests

URL = 'https://www2.cetip.com.br/ConsultarTaxaDi/ConsultarTaxaDICetip.aspx'

# Criando a variável data e hora

for _ in range(0, 10):

  data_e_hora = datetime.now()
  data = datetime.strftime(data_e_hora, '%Y/%m/%d')
  hora = datetime.strftime(data_e_hora, '%H:%M:%S')

  # Captando a taxa CDI do site da B3

  try:
    response = requests.get(URL)
    response.raise_for_status()
  except requests.HTTPError as exc:
    print("Dado não encontrado, continuando.")
    cdi = None
  except Exception as exc:
    print("Erro, parando a execução.")
    raise exc
  else:
    dado = json.loads(response.text)
    cdi = float(dado['taxa'].replace(',', '.')) + (random() - 0.5)

  # Verificando se o arquivo "taxa-cdi.csv" existe

  if os.path.exists('./taxa-cdi.csv') == False:

    with open(file='./taxa-cdi.csv', mode='w', encoding='utf8') as fp:
      fp.write('data,hora,taxa\n')

  # Salvando dados no arquivo "taxa-cdi.csv"

  with open(file='./taxa-cdi.csv', mode='a', encoding='utf8') as fp:
    fp.write(f'{data},{hora},{cdi}\n')

  time.sleep(2 + (random() - 0.5))

print("Sucesso")
# Out:
# Sucesso

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Script de Visualização

# %% [markdown]
# Já o *script* para gerar um grafico da taxa CDI do site da B3 foi adaptado para utilizar o pacote Pandas. Na sua máquina, crie o arquivo `visualizacao.py` com o `script` abaixo e execute-o com o comando:
#
# ```shell
# python visualizacao.py <nome-do-grafico>
# ```
#
# O *script* espera um parametro de entrada com o nome do gráfico, portanto substitua o `<nome-do-grafico>` pelo nome do seu gráfico. No final, você deve ter uma imagem no formato png com o nome passado via parametro contendo a visualização dos dados gerados pelo *script* de extração..

# %%
import csv
from sys import argv

import pandas as pd
import seaborn as sns

# Extraindo as colunas hora e taxa

df = pd.read_csv('./taxa-cdi.csv')

# Salvando no grafico

grafico = sns.lineplot(x=df['hora'], y=df['taxa'])
_ = grafico.set_xticklabels(labels=df['hora'], rotation=90)
grafico.get_figure().savefig(f"{argv[1]}.png")
# Out:
# <ipython-input-5-04381e656c0b>:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   _ = grafico.set_xticklabels(labels=df['hora'], rotation=90)

# %% [markdown]
# ---

# %% [markdown]
# ## 3\. Combinando os scripts de extração e visualização.

# %% [markdown]
# Combine os *scripts* `visualizacao.py` e `extracao.py` no arquivo `analise.py` e execute-o na sua máquina, ele deve retornar os mesmos resultados: o arquivo csv e a imagem no formato png com o título escolhido via parametro de entrada. Procure seguir a organização proposta na aula (PEP8).
#
# ```shell
# python analise.py <nome-do-grafico>
# ```
#
# Além disso, copie o código na célula abaixo e tire os print's da tela executando o script na máquina como evidência para que o tutor possa avaliar seu exercício.

# %%
# combinação dos scripts de extração e visualização

# Standard library imports: 1. Script de Extração
import os
import time
import json
from random import random
from datetime import datetime
# Standard library imports: 2. Script de Visualização
import csv  # Unused import statement 'import csv'
from sys import argv

# Related third party imports: 1. Script de Extração
import requests
# Related third party imports: 2. Script de Visualização
import pandas as pd
import seaborn as sns


# 1. Script de Extração:

URL = 'https://www2.cetip.com.br/ConsultarTaxaDi/ConsultarTaxaDICetip.aspx'

# Criando a variável data e hora

for _ in range(0, 10):

  data_e_hora = datetime.now()
  data = datetime.strftime(data_e_hora, '%Y/%m/%d')
  hora = datetime.strftime(data_e_hora, '%H:%M:%S')

  # Captando a taxa CDI do site da B3

  try:
    response = requests.get(URL)
    response.raise_for_status()
  except requests.HTTPError as exc:
    print("Dado não encontrado, continuando.")
    cdi = None
  except Exception as exc:
    print("Erro, parando a execução.")
    raise exc
  else:
    dado = json.loads(response.text)
    cdi = float(dado['taxa'].replace(',', '.')) + (random() - 0.5)

  # Verificando se o arquivo "taxa-cdi.csv" existe

  if not os.path.exists('./taxa-cdi.csv'):

    with open(file='./taxa-cdi.csv', mode='w', encoding='utf8') as fp:
      fp.write('data,hora,taxa\n')

  # Salvando dados no arquivo "taxa-cdi.csv"

  with open(file='./taxa-cdi.csv', mode='a', encoding='utf8') as fp:
    fp.write(f'{data},{hora},{cdi}\n')

  time.sleep(2 + (random() - 0.5))

print("Sucesso")


# 2. Script de Visualização:

# Extraindo as colunas hora e taxa

df = pd.read_csv('./taxa-cdi.csv')

# Salvando no gráfico

grafico = sns.lineplot(x=df['hora'], y=df['taxa'])
_ = grafico.set_xticklabels(labels=df['hora'], rotation=90)
grafico.get_figure().savefig(f"{argv[1]}.png")
# Out:
# Sucesso
# <ipython-input-6-809d6462a0af>:73: UserWarning: FixedFormatter should only be used together with FixedLocator
#   _ = grafico.set_xticklabels(labels=df['hora'], rotation=90)

# %% [markdown]
# ---
