# %% [markdown]
# <a href="https://colab.research.google.com/github/junior141981/volta-zero/blob/main/Mod04_Tarefa_aulas_06_a_08certo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
r_mun_rj = requests.get("https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl")

r_mun_rj.status_code
# Out:
# 200

# %%
# 2) Seu código aqui
df_mun_rj = pd.DataFrame(r_mun_rj.json()['items'])
df_mun_rj
# Out:
#       id_pleito tipo_interessado                   interessado  cod_ibge  uf  \
# 0         26058        Município                     Guaratuba   4109609  PR
# 1          5650        Município                         Bauru   3506003  SP
# 2         25118        Município                         Feliz   4308102  RS
# 3         26466        Município                   Porto Feliz   3540606  SP
# 4         27434        Município                    Alagoinhas   2900702  BA
# ...         ...              ...                           ...       ...  ..
# 4995       8997        Município                   Divisa Nova   3122405  MG
# 4996       9106        Município                    São Miguel   2412500  RN
# 4997      19076        Município               Salto do Lontra   4123006  PR
# 4998       8816        Município  Santo Antônio do Aventureiro   3160009  MG
# 4999      18185        Município                      Alegrete   4300406  RS
#
#                    num_pvl             status          num_processo  \
# 0     PVL02.001284/2017-98           Deferido  17944.101444/2017-61
# 1                     None           Deferido  17944.000162/2014-02
# 2     PVL02.000852/2017-33           Deferido  17944.000648/2017-85
# 3     PVL02.002038/2017-53           Deferido  17944.102374/2017-68
# 4     PVL02.000105/2018-86  Deferido (PVL-IF)                  None
# ...                    ...                ...                   ...
# 4995                  None           Deferido  17944.000881/2010-91
# 4996                  None          Arquivado  17944.000904/2008-43
# 4997  00000.000000/2010-13           Deferido  17944.000539/2015-04
# 4998                  None           Deferido  17944.000846/2010-72
# 4999                  None       Regularizado  19406.000737/2008-53
#
#             data_protocolo                tipo_operacao  \
# 0     2017-12-04T18:06:57Z  Operação contratual interna
# 1     2014-07-07T03:00:00Z  Operação contratual interna
# 2     2017-08-10T22:25:32Z  Operação contratual interna
# 3     2017-11-27T11:40:17Z  Operação contratual interna
# 4                     None  Operação contratual interna
# ...                    ...                          ...
# 4995  2011-04-04T03:00:00Z  Operação contratual interna
# 4996  2008-04-04T03:00:00Z  Operação contratual interna
# 4997  2015-06-24T03:00:00Z  Operação contratual interna
# 4998  2010-06-07T03:00:00Z  Operação contratual interna
# 4999  2009-01-22T02:00:00Z  Operação contratual interna
#
#                                              finalidade  \
# 0                                        Infraestrutura
# 1     PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 2                                        Infraestrutura
# 3                                        Infraestrutura
# 4                                                  PMAT
# ...                                                 ...
# 4995                                       Provias 2010
# 4996                                Caminho da Escola 2
# 4997     Aquisição de máquinas, equipamentos e veículos
# 4998                                     Infraestrutura
# 4999                   Regularização de Dívida - Outros
#
#                           tipo_credor  \
# 0     Instituição Financeira Nacional
# 1     Instituição Financeira Nacional
# 2     Instituição Financeira Nacional
# 3     Instituição Financeira Nacional
# 4     Instituição Financeira Nacional
# ...                               ...
# 4995  Instituição Financeira Nacional
# 4996  Instituição Financeira Nacional
# 4997  Instituição Financeira Nacional
# 4998  Instituição Financeira Nacional
# 4999                    Pessoa Física
#
#                                                  credor moeda        valor  \
# 0                      Agência de Fomento do Paraná S/A  Real   4000000.00
# 1                               Caixa Econômica Federal  Real   3421305.00
# 2     BADESUL Desenvolvimento S.A. - Agência de Fome...  Real   1500000.00
# 3             Agência de Fomento do Estado de São Paulo  Real  13643973.57
# 4                               Caixa Econômica Federal  Real   4851450.00
# ...                                                 ...   ...          ...
# 4995                                Banco do Brasil S/A  Real    250000.00
# 4996                                Banco do Brasil S/A  Real    582750.00
# 4997                   Agência de Fomento do Paraná S/A  Real    430000.00
# 4998       Banco de Desenvolvimento de Minas Gerais S/A  Real    600000.00
# 4999                                      Pessoa Física  Real    350000.00
#
#       pvl_assoc_divida  pvl_contradado_credor data_status
# 0                    0                      0  08/12/2017
# 1                    1                      0  18/08/2014
# 2                    1                      0  15/08/2017
# 3                    1                      0  04/12/2017
# 4                    1                      1  21/11/2018
# ...                ...                    ...         ...
# 4995                 0                      0  20/04/2011
# 4996                 0                      0  26/08/2008
# 4997                 1                      0  30/07/2015
# 4998                 1                      0  02/07/2010
# 4999                 0                      0  04/02/2009
#
# [5000 rows x 18 columns]

# %%
# 3) Seu código aqui
df_mun_rj['uf'].value_counts()
# Out:
# PR    1015
# MG     994
# RS     754
# SC     607
# SP     583
# BA     196
# GO      98
# CE      89
# MT      85
# MS      70
# RJ      64
# PE      48
# ES      46
# TO      44
# RO      41
# MA      38
# PI      34
# RN      33
# PB      32
# PA      31
# SE      24
# AL      24
# AC      15
# DF      11
# AM      10
# AP       8
# RR       6
# Name: uf, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consultar_PVL(uf:str='SP', tipo_interessado:str='Estado') -> pd.DataFrame:
    url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf={}&tipo_interessado={}'.format(
        uf,
        tipo_interessado)
    r_uf = requests.get(url)
    return pd.DataFrame(r_uf.json()['items'])

consultar_PVL('RJ', 'Município')
# Out:
#      id_pleito tipo_interessado          interessado  cod_ibge  uf  \
# 0         5464        Município           Petrópolis   3303906  RJ
# 1        11415        Município              Niterói   3303302  RJ
# 2        11032        Município           Petrópolis   3303906  RJ
# 3        10923        Município              Niterói   3303302  RJ
# 4        60633        Município          Nova Iguaçu   3303500  RJ
# ..         ...              ...                  ...       ...  ..
# 255       8839        Município          Porciúncula   3304102  RJ
# 256      58189        Município        Nova Friburgo   3303401  RJ
# 257      42252        Município             Itatiaia   3302254  RJ
# 258      65245        Município       Rio de Janeiro   3304557  RJ
# 259      66686        Município  São Pedro da Aldeia   3305208  RJ
#
#                   num_pvl                                             status  \
# 0                    None                                          Arquivado
# 1                    None                                           Deferido
# 2                    None                                 Arquivado a pedido
# 3                    None                                           Deferido
# 4    PVL02.005341/2022-75                                           Deferido
# ..                    ...                                                ...
# 255                  None                                          Arquivado
# 256  PVL02.003661/2022-91                    Em retificação pelo interessado
# 257  PVL02.000042/2020-82  Encaminhado à PGFN com manifestação técnica fa...
# 258  PVL02.001203/2023-06  Encaminhado à PGFN com manifestação técnica fa...
# 259  PVL02.003206/2023-76                                           Deferido
#
#              num_processo        data_protocolo  \
# 0    17944.000120/2010-30  2010-05-17T03:00:00Z
# 1    17944.001438/2008-13  2008-09-15T03:00:00Z
# 2    17944.001341/2013-78  2017-03-31T17:18:53Z
# 3    17944.001314/2014-86  2015-11-12T02:00:00Z
# 4    17944.102616/2022-81  2022-07-27T19:10:17Z
# ..                    ...                   ...
# 255  17944.000850/2008-16  2008-09-01T03:00:00Z
# 256  17944.101850/2022-91  2023-11-10T20:12:14Z
# 257  17944.101489/2020-31  2020-05-19T13:29:59Z
# 258  17944.102641/2023-45  2023-07-26T13:58:05Z
# 259  17944.104387/2023-10  2023-09-12T15:46:32Z
#
#                                          tipo_operacao  \
# 0                          Operação contratual interna
# 1                          Operação contratual interna
# 2    Operação contratual interna (com garantia da U...
# 3                          Operação contratual interna
# 4                          Operação contratual interna
# ..                                                 ...
# 255                        Operação contratual interna
# 256  Operação contratual interna (com garantia da U...
# 257  Operação contratual interna (com garantia da U...
# 258  Operação contratual interna (com garantia da U...
# 259                        Operação contratual interna
#
#                                             finalidade  \
# 0                             PAC - Pró-Moradia - 2009
# 1                            PAC - Saneamento - 2008 B
# 2    PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 3    PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 4                                       Infraestrutura
# ..                                                 ...
# 255                                Caminho da Escola 2
# 256                                     Infraestrutura
# 257                                     Infraestrutura
# 258                                     Pró-Transporte
# 259                                     Infraestrutura
#
#                          tipo_credor                   credor moeda  \
# 0    Instituição Financeira Nacional  Caixa Econômica Federal  Real
# 1    Instituição Financeira Nacional  Caixa Econômica Federal  Real
# 2    Instituição Financeira Nacional  Caixa Econômica Federal  Real
# 3    Instituição Financeira Nacional  Caixa Econômica Federal  Real
# 4    Instituição Financeira Nacional  Caixa Econômica Federal  Real
# ..                               ...                      ...   ...
# 255  Instituição Financeira Nacional      Banco do Brasil S/A  Real
# 256  Instituição Financeira Nacional  Caixa Econômica Federal  Real
# 257  Instituição Financeira Nacional      Banco do Brasil S/A  Real
# 258  Instituição Financeira Nacional  Caixa Econômica Federal  Real
# 259  Instituição Financeira Nacional      Banco do Brasil S/A  Real
#
#             valor  pvl_assoc_divida  pvl_contradado_credor data_status
# 0    1.900000e+07                 0                      0  23/12/2010
# 1    9.700000e+06                 0                      0  23/09/2008
# 2    3.704687e+07                 0                      0  19/12/2017
# 3    1.000000e+07                 0                      0  18/11/2015
# 4    1.000000e+08                 0                      0  01/08/2022
# ..            ...               ...                    ...         ...
# 255  1.455000e+05                 0                      0  13/11/2008
# 256  3.000000e+07                 0                      0  24/11/2023
# 257  3.000000e+07                 1                      1  21/05/2020
# 258  6.459310e+08                 0                      1  03/08/2023
# 259  1.200000e+07                 0                      1  19/09/2023
#
# [260 rows x 18 columns]

# %%
# 2) Seu código aqui
df_estado_mg = consultar_PVL('MG', 'Estado')
print("Quantidade de solicitações do tipo Estado para Minas Gerais com status em 'Arquivado por decurso de prazo':")
print(df_estado_mg[df_estado_mg['status'] == 'Arquivado por decurso de prazo'].shape[0])
# Out:
# Quantidade de solicitações do tipo Estado para Minas Gerais com status em 'Arquivado por decurso de prazo':
# 1

# %%
# 3) Seu código aqui
df_estado_ba = consultar_PVL('BA', 'Município')
print('O Município da Bahia com mais solicitões deferidas:')
print('{} com {} solicitações deferidas.'.format(
    df_estado_ba['interessado'].value_counts().index[0].upper(),
    df_estado_ba['interessado'].value_counts()[0]))
# Out:
# O Município da Bahia com mais solicitões deferidas:
# CAMAÇARI com 19 solicitações deferidas.

# %%
# 4) Seu código aqui
df_pvls_estado_ba = consultar_PVL('BA', 'Estado')
df_pvls_estado_ba.to_csv('pvls_estado_ba.csv', index=False)
